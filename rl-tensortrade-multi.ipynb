# %%
# !python --version
# Out:
# Python 3.7.3

# %%
from tensortrade.data.cdd import CryptoDataDownload
import pandas as pd

# %% [markdown]
# #### Installing used libs

# %%
# !pip install -U tensortrade==1.0.3 ta matplotlib tensorboardX scikit-learn
# Out:
# Requirement already satisfied: tensortrade==1.0.3 in ./test/lib/python3.7/site-packages (1.0.3)
# Requirement already satisfied: ta in ./test/lib/python3.7/site-packages (0.7.0)
# Requirement already satisfied: matplotlib in ./test/lib/python3.7/site-packages (3.4.2)
# Requirement already satisfied: tensorboardX in ./test/lib/python3.7/site-packages (2.2)
# Requirement already satisfied: scikit-learn in ./test/lib/python3.7/site-packages (0.24.2)
# Requirement already satisfied: numpy>=1.17.0 in ./test/lib/python3.7/site-packages (from tensortrade==1.0.3) (1.19.5)
# Requirement already satisfied: stochastic>=0.6.0 in ./test/lib/python3.7/site-packages (from tensortrade==1.0.3) (0.6.0)
# Requirement already satisfied: tensorflow>=2.1.0 in ./test/lib/python3.7/site-packages (from tensortrade==1.0.3) (2.5.0)
# Requirement already satisfied: ipython>=7.12.0 in ./test/lib/python3.7/site-packages (from tensortrade==1.0.3) (7.23.1)
# Requirement already satisfied: pandas>=0.25.0 in ./test/lib/python3.7/site-packages (from tensortrade==1.0.3) (1.2.4)
# Requirement already satisfied: plotly>=4.5.0 in ./test/lib/python3.7/site-packages (from tensortrade==1.0.3) (4.14.3)
# Requirement already satisfied: pyyaml>=5.1.2 in ./test/lib/python3.7/site-packages (from tensortrade==1.0.3) (5.4.1)
# Requirement already satisfied: gym>=0.14.0 in ./test/lib/python3.7/site-packages (from tensortrade==1.0.3) (0.18.3)
# Requirement already satisfied: cycler>=0.10 in ./test/lib/python3.7/site-packages (from matplotlib) (0.10.0)
# Requirement already satisfied: pyparsing>=2.2.1 in ./test/lib/python3.7/site-packages (from matplotlib) (2.4.7)
# Requirement already satisfied: python-dateutil>=2.7 in ./test/lib/python3.7/site-packages (from matplotlib) (2.8.1)
# Requirement already satisfied: pillow>=6.2.0 in ./test/lib/python3.7/site-packages (from matplotlib) (8.2.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in ./test/lib/python3.7/site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: six in ./test/lib/python3.7/site-packages (from cycler>=0.10->matplotlib) (1.15.0)
# Requirement already satisfied: scipy in ./test/lib/python3.7/site-packages (from gym>=0.14.0->tensortrade==1.0.3) (1.6.3)
# Requirement already satisfied: pyglet<=1.5.15,>=1.4.0 in ./test/lib/python3.7/site-packages (from gym>=0.14.0->tensortrade==1.0.3) (1.5.15)
# Requirement already satisfied: cloudpickle<1.7.0,>=1.2.0 in ./test/lib/python3.7/site-packages (from gym>=0.14.0->tensortrade==1.0.3) (1.6.0)
# Requirement already satisfied: traitlets>=4.2 in ./test/lib/python3.7/site-packages (from ipython>=7.12.0->tensortrade==1.0.3) (5.0.5)
# Requirement already satisfied: backcall in ./test/lib/python3.7/site-packages (from ipython>=7.12.0->tensortrade==1.0.3) (0.2.0)
# Requirement already satisfied: pickleshare in ./test/lib/python3.7/site-packages (from ipython>=7.12.0->tensortrade==1.0.3) (0.7.5)
# Requirement already satisfied: matplotlib-inline in ./test/lib/python3.7/site-packages (from ipython>=7.12.0->tensortrade==1.0.3) (0.1.2)
# Requirement already satisfied: pexpect>4.3 in ./test/lib/python3.7/site-packages (from ipython>=7.12.0->tensortrade==1.0.3) (4.8.0)
# Requirement already satisfied: jedi>=0.16 in ./test/lib/python3.7/site-packages (from ipython>=7.12.0->tensortrade==1.0.3) (0.18.0)
# Requirement already satisfied: setuptools>=18.5 in ./test/lib/python3.7/site-packages (from ipython>=7.12.0->tensortrade==1.0.3) (57.0.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in ./test/lib/python3.7/site-packages (from ipython>=7.12.0->tensortrade==1.0.3) (3.0.18)
# Requirement already satisfied: pygments in ./test/lib/python3.7/site-packages (from ipython>=7.12.0->tensortrade==1.0.3) (2.9.0)
# Requirement already satisfied: decorator in ./test/lib/python3.7/site-packages (from ipython>=7.12.0->tensortrade==1.0.3) (5.0.9)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in ./test/lib/python3.7/site-packages (from jedi>=0.16->ipython>=7.12.0->tensortrade==1.0.3) (0.8.2)
# Requirement already satisfied: pytz>=2017.3 in ./test/lib/python3.7/site-packages (from pandas>=0.25.0->tensortrade==1.0.3) (2021.1)
# Requirement already satisfied: ptyprocess>=0.5 in ./test/lib/python3.7/site-packages (from pexpect>4.3->ipython>=7.12.0->tensortrade==1.0.3) (0.7.0)
# Requirement already satisfied: retrying>=1.3.3 in ./test/lib/python3.7/site-packages (from plotly>=4.5.0->tensortrade==1.0.3) (1.3.3)
# Requirement already satisfied: wcwidth in ./test/lib/python3.7/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=7.12.0->tensortrade==1.0.3) (0.2.5)
# Requirement already satisfied: gast==0.4.0 in ./test/lib/python3.7/site-packages (from tensorflow>=2.1.0->tensortrade==1.0.3) (0.4.0)
# Requirement already satisfied: astunparse~=1.6.3 in ./test/lib/python3.7/site-packages (from tensorflow>=2.1.0->tensortrade==1.0.3) (1.6.3)
# Requirement already satisfied: flatbuffers~=1.12.0 in ./test/lib/python3.7/site-packages (from tensorflow>=2.1.0->tensortrade==1.0.3) (1.12)
# Requirement already satisfied: absl-py~=0.10 in ./test/lib/python3.7/site-packages (from tensorflow>=2.1.0->tensortrade==1.0.3) (0.12.0)
# Requirement already satisfied: typing-extensions~=3.7.4 in ./test/lib/python3.7/site-packages (from tensorflow>=2.1.0->tensortrade==1.0.3) (3.7.4.3)
# Requirement already satisfied: google-pasta~=0.2 in ./test/lib/python3.7/site-packages (from tensorflow>=2.1.0->tensortrade==1.0.3) (0.2.0)
# Requirement already satisfied: tensorflow-estimator<2.6.0,>=2.5.0rc0 in ./test/lib/python3.7/site-packages (from tensorflow>=2.1.0->tensortrade==1.0.3) (2.5.0)
# Requirement already satisfied: termcolor~=1.1.0 in ./test/lib/python3.7/site-packages (from tensorflow>=2.1.0->tensortrade==1.0.3) (1.1.0)
# Requirement already satisfied: wrapt~=1.12.1 in ./test/lib/python3.7/site-packages (from tensorflow>=2.1.0->tensortrade==1.0.3) (1.12.1)
# Requirement already satisfied: wheel~=0.35 in ./test/lib/python3.7/site-packages (from tensorflow>=2.1.0->tensortrade==1.0.3) (0.36.2)
# Requirement already satisfied: grpcio~=1.34.0 in ./test/lib/python3.7/site-packages (from tensorflow>=2.1.0->tensortrade==1.0.3) (1.34.1)
# Requirement already satisfied: opt-einsum~=3.3.0 in ./test/lib/python3.7/site-packages (from tensorflow>=2.1.0->tensortrade==1.0.3) (3.3.0)
# Requirement already satisfied: tensorboard~=2.5 in ./test/lib/python3.7/site-packages (from tensorflow>=2.1.0->tensortrade==1.0.3) (2.5.0)
# Requirement already satisfied: h5py~=3.1.0 in ./test/lib/python3.7/site-packages (from tensorflow>=2.1.0->tensortrade==1.0.3) (3.1.0)
# Requirement already satisfied: keras-preprocessing~=1.1.2 in ./test/lib/python3.7/site-packages (from tensorflow>=2.1.0->tensortrade==1.0.3) (1.1.2)
# Requirement already satisfied: protobuf>=3.9.2 in ./test/lib/python3.7/site-packages (from tensorflow>=2.1.0->tensortrade==1.0.3) (3.17.1)
# Requirement already satisfied: keras-nightly~=2.5.0.dev in ./test/lib/python3.7/site-packages (from tensorflow>=2.1.0->tensortrade==1.0.3) (2.5.0.dev2021032900)
# Requirement already satisfied: cached-property in ./test/lib/python3.7/site-packages (from h5py~=3.1.0->tensorflow>=2.1.0->tensortrade==1.0.3) (1.5.2)
# Requirement already satisfied: requests<3,>=2.21.0 in ./test/lib/python3.7/site-packages (from tensorboard~=2.5->tensorflow>=2.1.0->tensortrade==1.0.3) (2.25.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in ./test/lib/python3.7/site-packages (from tensorboard~=2.5->tensorflow>=2.1.0->tensortrade==1.0.3) (1.8.0)
# Requirement already satisfied: markdown>=2.6.8 in ./test/lib/python3.7/site-packages (from tensorboard~=2.5->tensorflow>=2.1.0->tensortrade==1.0.3) (3.3.4)
# Requirement already satisfied: google-auth<2,>=1.6.3 in ./test/lib/python3.7/site-packages (from tensorboard~=2.5->tensorflow>=2.1.0->tensortrade==1.0.3) (1.30.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in ./test/lib/python3.7/site-packages (from tensorboard~=2.5->tensorflow>=2.1.0->tensortrade==1.0.3) (0.6.1)
# Requirement already satisfied: werkzeug>=0.11.15 in ./test/lib/python3.7/site-packages (from tensorboard~=2.5->tensorflow>=2.1.0->tensortrade==1.0.3) (2.0.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in ./test/lib/python3.7/site-packages (from tensorboard~=2.5->tensorflow>=2.1.0->tensortrade==1.0.3) (0.4.4)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in ./test/lib/python3.7/site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow>=2.1.0->tensortrade==1.0.3) (4.2.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in ./test/lib/python3.7/site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow>=2.1.0->tensortrade==1.0.3) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in ./test/lib/python3.7/site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow>=2.1.0->tensortrade==1.0.3) (4.7.2)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in ./test/lib/python3.7/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.5->tensorflow>=2.1.0->tensortrade==1.0.3) (1.3.0)
# Requirement already satisfied: importlib-metadata in ./test/lib/python3.7/site-packages (from markdown>=2.6.8->tensorboard~=2.5->tensorflow>=2.1.0->tensortrade==1.0.3) (4.0.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in ./test/lib/python3.7/site-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow>=2.1.0->tensortrade==1.0.3) (0.4.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in ./test/lib/python3.7/site-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow>=2.1.0->tensortrade==1.0.3) (1.26.4)
# Requirement already satisfied: chardet<5,>=3.0.2 in ./test/lib/python3.7/site-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow>=2.1.0->tensortrade==1.0.3) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in ./test/lib/python3.7/site-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow>=2.1.0->tensortrade==1.0.3) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in ./test/lib/python3.7/site-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow>=2.1.0->tensortrade==1.0.3) (2020.12.5)
# Requirement already satisfied: oauthlib>=3.0.0 in ./test/lib/python3.7/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.5->tensorflow>=2.1.0->tensortrade==1.0.3) (3.1.0)
# Requirement already satisfied: ipython-genutils in ./test/lib/python3.7/site-packages (from traitlets>=4.2->ipython>=7.12.0->tensortrade==1.0.3) (0.2.0)
# Requirement already satisfied: joblib>=0.11 in ./test/lib/python3.7/site-packages (from scikit-learn) (1.0.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in ./test/lib/python3.7/site-packages (from scikit-learn) (2.1.0)
# Requirement already satisfied: zipp>=0.5 in ./test/lib/python3.7/site-packages (from importlib-metadata->markdown>=2.6.8->tensorboard~=2.5->tensorflow>=2.1.0->tensortrade==1.0.3) (3.4.1)

# %% [markdown]
# #### Checking if installed version of Tensortrade is the version 1.0.3

# %%
import tensortrade
print(tensortrade.__version__)
# Out:
# 1.0.3

# %% [markdown]
# #### Importing used libs

# %%
import random

import ta
import pandas as pd

import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler

import tensortrade.env.default as default
from tensortrade.feed.core import Stream, DataFeed, NameSpace
from tensortrade.oms.exchanges import Exchange
from tensortrade.oms.services.execution.simulated import execute_order
from tensortrade.oms.instruments import USD, BTC, ETH
from tensortrade.oms.wallets import Wallet, Portfolio
from tensortrade.agents import A2CAgent
import tensortrade.stochastic as sp 
from tensortrade.oms.instruments import Instrument

# %% [markdown]
# #### Helper functions used to generate technical analysis features and create the environment for agent training and testing

# %%
def fetchTaFeatures(data):
    data = ta.add_all_ta_features(data, 'open', 'high', 'low', 'close', 'volume', fillna=True)
    data.columns = [name.lower() for name in data.columns]
    return data

def createEnv(config):

    coins = ["coin{}".format(x) for x in range(5)]
    bitfinex_streams = []

    with NameSpace("bitfinex"):
        for coin in coins:
            coinColumns = filter(lambda name: name.startswith(coin), config["data"].columns)
            bitfinex_streams += [
                Stream.source(list(config["data"][c]), dtype="float").rename(c) for c in coinColumns
            ]





    feed = DataFeed(bitfinex_streams)
    
    streams = []
    for coin in coins:
         streams.append(Stream.source(list(data[coin+":"+"close"]), dtype="float").rename("USD-"+coin))
    streams = tuple(streams)


    bitstamp = Exchange("bitfinex", service=execute_order)(
        Stream.source(list(data["coin0:close"]), dtype="float").rename("USD-BTC"),
        Stream.source(list(data["coin1:close"]), dtype="float").rename("USD-ETH"),
        Stream.source(list(data["coin2:close"]), dtype="float").rename("USD-TTC1"),
        Stream.source(list(data["coin3:close"]), dtype="float").rename("USD-TTC2"),
        Stream.source(list(data["coin4:close"]), dtype="float").rename("USD-TTC3"),
    
    )
    
    TTC1 = Instrument("TTC1", 8, "TensorTrade Coin1")
    TTC2 = Instrument("TTC2", 8, "TensorTrade Coin2")
    TTC3 = Instrument("TTC3", 8, "TensorTrade Coin3")
    
    
    cash = Wallet(bitstamp, 10000 * USD)
    asset = Wallet(bitstamp, 0 * BTC)
    asset1 = Wallet(bitstamp, 0 * ETH)
    asset2 = Wallet(bitstamp, 0 * TTC1)
    asset3 = Wallet(bitstamp, 0 * TTC2)
    asset4 = Wallet(bitstamp, 0 * TTC3)

    portfolio = Portfolio(USD, [cash, asset, asset1, asset2, asset3, asset4
        
    ])
    
    env = default.create(
      feed=feed,
      portfolio=portfolio,
      action_scheme="managed-risk", # mudei aqui e parcialmente funcionou
      reward_scheme='risk-adjusted', # substituir por sortino
      window_size=config["window_size"]
    )
    
    return env

# %% [markdown]
# #### Creating data with stochastic process for training

# %%
cdd = CryptoDataDownload()

coins = ["coin{}".format(x) for x in range(5)]
dfs = []
for coin in coins:
    df = sp.fbm(
    base_price=10000,
    base_volume=5000,
    start_date="2010-01-01",
    times_to_generate=100,
    time_frame='1H').add_prefix(coin+":")

    ta.add_all_ta_features(
    df,
    colprefix=coin+":",
    **{k: coin+":" + k for k in ['open', 'high', 'low', 'close', 'volume']}    )
    
    dfs.append(df)

data = pd.concat(dfs, axis=1)
# Out:
# /home/leandro/Documentos/ReinforcementLearningTrading/test/lib/python3.7/site-packages/ta/trend.py:768: RuntimeWarning: invalid value encountered in double_scalars
#   dip[i] = 100 * (self._dip[i] / self._trs[i])
# /home/leandro/Documentos/ReinforcementLearningTrading/test/lib/python3.7/site-packages/ta/trend.py:772: RuntimeWarning: invalid value encountered in double_scalars
#   din[i] = 100 * (self._din[i] / self._trs[i])
# /home/leandro/Documentos/ReinforcementLearningTrading/test/lib/python3.7/site-packages/ta/trend.py:768: RuntimeWarning: invalid value encountered in double_scalars
#   dip[i] = 100 * (self._dip[i] / self._trs[i])
# /home/leandro/Documentos/ReinforcementLearningTrading/test/lib/python3.7/site-packages/ta/trend.py:772: RuntimeWarning: invalid value encountered in double_scalars
#   din[i] = 100 * (self._din[i] / self._trs[i])
# /home/leandro/Documentos/ReinforcementLearningTrading/test/lib/python3.7/site-packages/ta/trend.py:768: RuntimeWarning: invalid value encountered in double_scalars
#   dip[i] = 100 * (self._dip[i] / self._trs[i])
# /home/leandro/Documentos/ReinforcementLearningTrading/test/lib/python3.7/site-packages/ta/trend.py:772: RuntimeWarning: invalid value encountered in double_scalars
#   din[i] = 100 * (self._din[i] / self._trs[i])
# /home/leandro/Documentos/ReinforcementLearningTrading/test/lib/python3.7/site-packages/ta/trend.py:768: RuntimeWarning: invalid value encountered in double_scalars
#   dip[i] = 100 * (self._dip[i] / self._trs[i])
# /home/leandro/Documentos/ReinforcementLearningTrading/test/lib/python3.7/site-packages/ta/trend.py:772: RuntimeWarning: invalid value encountered in double_scalars
#   din[i] = 100 * (self._din[i] / self._trs[i])
# /home/leandro/Documentos/ReinforcementLearningTrading/test/lib/python3.7/site-packages/ta/trend.py:768: RuntimeWarning: invalid value encountered in double_scalars
#   dip[i] = 100 * (self._dip[i] / self._trs[i])
# /home/leandro/Documentos/ReinforcementLearningTrading/test/lib/python3.7/site-packages/ta/trend.py:772: RuntimeWarning: invalid value encountered in double_scalars
#   din[i] = 100 * (self._din[i] / self._trs[i])

# %%
# 2010-01-05 01:00:00         -28.035099         -18.318119
# 2010-01-05 02:00:00         -47.120707         -11.872555
# 2010-01-05 03:00:00         -70.895657         -10.338598
#
#                      coin4:momentum_kama  coin4:momentum_roc  \
# 2010-01-01 00:00:00                  NaN                 NaN
# 2010-01-01 01:00:00                  NaN                 NaN
# 2010-01-01 02:00:00                  NaN                 NaN
# 2010-01-01 03:00:00                  NaN                 NaN
# 2010-01-01 04:00:00                  NaN                 NaN
# ...                                  ...                 ...
# 2010-01-04 23:00:00         10034.192301           -0.022327
# 2010-01-05 00:00:00         10034.312022           -0.005552
# 2010-01-05 01:00:00         10034.597447            0.000400
# 2010-01-05 02:00:00         10034.517959            0.008363
# 2010-01-05 03:00:00         10033.380376           -0.048467
#
#                      coin4:momentum_ppo  coin4:momentum_ppo_signal  \
# 2010-01-01 00:00:00                 NaN                        NaN
# 2010-01-01 01:00:00                 NaN                        NaN
# 2010-01-01 02:00:00                 NaN                        NaN
# 2010-01-01 03:00:00                 NaN                        NaN
# 2010-01-01 04:00:00                 NaN                        NaN
# ...                                 ...                        ...
# 2010-01-04 23:00:00           -0.011181                  -0.013152
# 2010-01-05 00:00:00           -0.006436                  -0.011808
# 2010-01-05 01:00:00           -0.004205                  -0.010288
# 2010-01-05 02:00:00            0.002242                  -0.007782
# 2010-01-05 03:00:00            0.011813                  -0.003863
#
#                      coin4:momentum_ppo_hist  coin4:others_dr  \
# 2010-01-01 00:00:00                      NaN        -0.413598
# 2010-01-01 01:00:00                      NaN        -0.075026
# 2010-01-01 02:00:00                      NaN         0.147511
# 2010-01-01 03:00:00                      NaN        -0.070139
# 2010-01-01 04:00:00                      NaN         0.143716
# ...                                      ...              ...
# 2010-01-04 23:00:00                 0.001971         0.190135
# 2010-01-05 00:00:00                 0.005372        -0.043536
# 2010-01-05 01:00:00                 0.006083         0.018682
# 2010-01-05 02:00:00                 0.010023        -0.146038
# 2010-01-05 03:00:00                 0.015676        -0.124420
#
#                      coin4:others_dlr  coin4:others_cr
# 2010-01-01 00:00:00               NaN         0.000000
# 2010-01-01 01:00:00         -0.075054        -0.075026
# 2010-01-01 02:00:00          0.147403         0.072374
# 2010-01-01 03:00:00         -0.070163         0.002185
# 2010-01-01 04:00:00          0.143613         0.145904
# ...                               ...              ...
# 2010-01-04 23:00:00          0.189955         0.570699
# 2010-01-05 00:00:00         -0.043546         0.526915
# 2010-01-05 01:00:00          0.018680         0.545695
# 2010-01-05 02:00:00         -0.146144         0.398860
# 2010-01-05 03:00:00         -0.124497         0.273944
#
# [100 rows x 440 columns]

# %% [markdown]
# #### Adding technical analysis features to the dataframe

# %% [markdown]
# #### Normalizing the data

# %%
scaler = MinMaxScaler()
# delColumns = ["coin{}:date".format(x) for x in range(5)]
# delColumns += ["coin{}:unix".format(x) for x in range(5)]

# data = data.drop(columns=delColumns)
norm_data = pd.DataFrame(scaler.fit_transform(data), columns=data.columns)

# %%
#                      coin4:momentum_kama  coin4:momentum_roc  \
# 2010-01-01 00:00:00                  NaN                 NaN
# 2010-01-01 01:00:00                  NaN                 NaN
# 2010-01-01 02:00:00                  NaN                 NaN
# 2010-01-01 03:00:00                  NaN                 NaN
# 2010-01-01 04:00:00                  NaN                 NaN
# ...                                  ...                 ...
# 2010-01-04 23:00:00         10034.192301           -0.022327
# 2010-01-05 00:00:00         10034.312022           -0.005552
# 2010-01-05 01:00:00         10034.597447            0.000400
# 2010-01-05 02:00:00         10034.517959            0.008363
# 2010-01-05 03:00:00         10033.380376           -0.048467
#
#                      coin4:momentum_ppo  coin4:momentum_ppo_signal  \
# 2010-01-01 00:00:00                 NaN                        NaN
# 2010-01-01 01:00:00                 NaN                        NaN
# 2010-01-01 02:00:00                 NaN                        NaN
# 2010-01-01 03:00:00                 NaN                        NaN
# 2010-01-01 04:00:00                 NaN                        NaN
# ...                                 ...                        ...
# 2010-01-04 23:00:00           -0.011181                  -0.013152
# 2010-01-05 00:00:00           -0.006436                  -0.011808
# 2010-01-05 01:00:00           -0.004205                  -0.010288
# 2010-01-05 02:00:00            0.002242                  -0.007782
# 2010-01-05 03:00:00            0.011813                  -0.003863
#
#                      coin4:momentum_ppo_hist  coin4:others_dr  \
# 2010-01-01 00:00:00                      NaN        -0.413598
# 2010-01-01 01:00:00                      NaN        -0.075026
# 2010-01-01 02:00:00                      NaN         0.147511
# 2010-01-01 03:00:00                      NaN        -0.070139
# 2010-01-01 04:00:00                      NaN         0.143716
# ...                                      ...              ...
# 2010-01-04 23:00:00                 0.001971         0.190135
# 2010-01-05 00:00:00                 0.005372        -0.043536
# 2010-01-05 01:00:00                 0.006083         0.018682
# 2010-01-05 02:00:00                 0.010023        -0.146038
# 2010-01-05 03:00:00                 0.015676        -0.124420
#
#                      coin4:others_dlr  coin4:others_cr
# 2010-01-01 00:00:00               NaN         0.000000
# 2010-01-01 01:00:00         -0.075054        -0.075026
# 2010-01-01 02:00:00          0.147403         0.072374
# 2010-01-01 03:00:00         -0.070163         0.002185
# 2010-01-01 04:00:00          0.143613         0.145904
# ...                               ...              ...
# 2010-01-04 23:00:00          0.189955         0.570699
# 2010-01-05 00:00:00         -0.043546         0.526915
# 2010-01-05 01:00:00          0.018680         0.545695
# 2010-01-05 02:00:00         -0.146144         0.398860
# 2010-01-05 03:00:00         -0.124497         0.273944
#
# [100 rows x 440 columns]

# %%
norm_data
# Out:
#     coin0:open  coin0:high  coin0:low  coin0:close  coin0:volume  \
# 0     0.496862    0.491473   0.495223     0.499483      0.533533
# 1     0.502620    0.594519   0.528470     0.604479      0.425844
# 2     0.609095    0.611755   0.606717     0.603297      0.772519
# 3     0.607735    0.629473   0.616197     0.613137      0.416876
# 4     0.614548    0.646490   0.601123     0.576139      0.451903
# ..         ...         ...        ...          ...           ...
# 95    0.780465    0.812373   0.792207     0.794275      0.431212
# 96    0.795542    0.787417   0.765959     0.739737      0.355247
# 97    0.738695    0.728880   0.698811     0.699773      0.664492
# 98    0.704080    0.694234   0.679694     0.698445      0.448025
# 99    0.701998    0.735302   0.726155     0.716416      0.620419
#
#     coin0:volume_adi  coin0:volume_obv  coin0:volume_cmf  coin0:volume_fi  \
# 0           0.895431          0.666418               NaN              NaN
# 1           0.993960          0.749609               NaN              NaN
# 2           1.000000          0.666211               NaN              NaN
# 3           0.990188          0.749397               NaN              NaN
# 4           0.889920          0.666190               NaN              NaN
# ..               ...               ...               ...              ...
# 95          0.188097          0.416801          0.527214         0.281905
# 96          0.087432          0.333652          0.399991         0.176183
# 97          0.069102          0.250318          0.300631         0.113176
# 98          0.146872          0.167113          0.278318         0.132981
# 99          0.119460          0.250421          0.154482         0.186809
#
#     coin0:volume_mfi  ...  coin4:momentum_wr  coin4:momentum_ao  \
# 0                NaN  ...                NaN                NaN
# 1                NaN  ...                NaN                NaN
# 2                NaN  ...                NaN                NaN
# 3                NaN  ...                NaN                NaN
# 4                NaN  ...                NaN                NaN
# ..               ...  ...                ...                ...
# 95          0.221361  ...           0.763001           0.290120
# 96          0.221586  ...           0.687088           0.311255
# 97          0.221798  ...           0.719649           0.348337
# 98          0.221847  ...           0.528793           0.416347
# 99          0.332946  ...           0.291043           0.432532
#
#     coin4:momentum_kama  coin4:momentum_roc  coin4:momentum_ppo  \
# 0                   NaN                 NaN                 NaN
# 1                   NaN                 NaN                 NaN
# 2                   NaN                 NaN                 NaN
# 3                   NaN                 NaN                 NaN
# 4                   NaN                 NaN                 NaN
# ..                  ...                 ...                 ...
# 95             0.711192            0.591797            0.285572
# 96             0.712448            0.601342            0.385089
# 97             0.715442            0.604728            0.431883
# 98             0.714608            0.609259            0.567103
# 99             0.702674            0.576924            0.767860
#
#     coin4:momentum_ppo_signal  coin4:momentum_ppo_hist  coin4:others_dr  \
# 0                         NaN                      NaN         0.000000
# 1                         NaN                      NaN         0.482865
# 2                         NaN                      NaN         0.800244
# 3                         NaN                      NaN         0.489835
# 4                         NaN                      NaN         0.794831
# ..                        ...                      ...              ...
# 95                   0.020428                 0.470608         0.861033
# 96                   0.076109                 0.554741         0.527775
# 97                   0.139152                 0.572308         0.616510
# 98                   0.243038                 0.669782         0.381589
# 99                   0.405507                 0.809589         0.412420
#
#     coin4:others_dlr  coin4:others_cr
# 0                NaN         0.242710
# 1           0.299417         0.190391
# 2           0.729683         0.293179
# 3           0.308877         0.244233
# 4           0.722353         0.344454
# ..               ...              ...
# 95          0.811986         0.640679
# 96          0.360359         0.610147
# 97          0.480714         0.623243
# 98          0.161918         0.520850
# 99          0.203786         0.433741
#
# [100 rows x 440 columns]

# %% [markdown]
# #### Creating a training environment with a 10-period window

# %%
config = {
            "window_size": 10,
            "data": norm_data
        }

env = createEnv(config)

# %% [markdown]
# #### Running agent training with 100,000 steps and 10 episodes.
# The agent will be saved in the "agents/" folder

# %%
# !mkdir -p agents/

agent = A2CAgent(env)
reward = agent.train(n_steps=20000, save_path="agents/", n_episodes = 10)
# Out:
# ====      AGENT ID: 13fc7a6b-aa96-4bd0-b52c-3da6df8c4e6a      ====
# ====      EPISODE ID (1/10): dd7d3634-ffc9-47e9-8fec-269f486398a5      ====
# ====      EPISODE ID (2/10): 43bd2e6f-0d73-4816-ba52-f869bcb317f6      ====
# /home/leandro/Documentos/ReinforcementLearningTrading/test/lib/python3.7/site-packages/tensorflow/python/keras/optimizer_v2/optimizer_v2.py:375: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")
# ====      EPISODE ID (3/10): 5636fe6d-dc29-4d25-944f-45c0fb12c046      ====
# ====      EPISODE ID (4/10): 08fa3bc8-c9fa-4452-9460-b4a7a62a5ca6      ====
# ====      EPISODE ID (5/10): 3adbf1d7-b806-4c2b-adb5-140e33339945      ====
# ====      EPISODE ID (6/10): 78d6bf0b-7b23-46be-b49a-bf626d84c23f      ====
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-a35fdbb55aa4> in <module>
#       2
#       3 agent = A2CAgent(env)
# ----> 4 reward = agent.train(n_steps=20000, save_path="agents/", n_episodes = 10)
#
# ~/Documentos/ReinforcementLearningTrading/test/lib/python3.7/site-packages/tensortrade/agents/a2c_agent.py in train(self, n_steps, n_episodes, save_every, save_path, callback, **kwargs)
#     221                                              learning_rate,
#     222                                              discount_factor,
# --> 223                                              entropy_c)
#     224
#     225                 if n_steps and steps_done >= n_steps:
#
# ~/Documentos/ReinforcementLearningTrading/test/lib/python3.7/site-packages/tensortrade/agents/a2c_agent.py in _apply_gradient_descent(self, memory, batch_size, learning_rate, discount_factor, entropy_c)
#     127         batch = A2CTransition(*zip(*transitions))
#     128
# --> 129         states = tf.convert_to_tensor(batch.state)
#     130         actions = tf.convert_to_tensor(batch.action)
#     131         rewards = tf.convert_to_tensor(batch.reward, dtype=tf.float32)
#
# ~/Documentos/ReinforcementLearningTrading/test/lib/python3.7/site-packages/tensorflow/python/util/dispatch.py in wrapper(*args, **kwargs)
#     204     """Call target, and fall back on dispatchers if there is a TypeError."""
#     205     try:
# --> 206       return target(*args, **kwargs)
#     207     except (TypeError, ValueError):
#     208       # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# ~/Documentos/ReinforcementLearningTrading/test/lib/python3.7/site-packages/tensorflow/python/framework/ops.py in convert_to_tensor_v2_with_dispatch(value, dtype, dtype_hint, name)
#    1429   """
#    1430   return convert_to_tensor_v2(
# -> 1431       value, dtype=dtype, dtype_hint=dtype_hint, name=name)
#    1432
#    1433
#
# ~/Documentos/ReinforcementLearningTrading/test/lib/python3.7/site-packages/tensorflow/python/framework/ops.py in convert_to_tensor_v2(value, dtype, dtype_hint, name)
#    1439       name=name,
#    1440       preferred_dtype=dtype_hint,
# -> 1441       as_ref=False)
#    1442
#    1443
#
# ~/Documentos/ReinforcementLearningTrading/test/lib/python3.7/site-packages/tensorflow/python/profiler/trace.py in wrapped(*args, **kwargs)
#     161         with Trace(trace_name, **trace_kwargs):
#     162           return func(*args, **kwargs)
# --> 163       return func(*args, **kwargs)
#     164
#     165     return wrapped
#
# ~/Documentos/ReinforcementLearningTrading/test/lib/python3.7/site-packages/tensorflow/python/framework/ops.py in convert_to_tensor(value, dtype, name, as_ref, preferred_dtype, dtype_hint, ctx, accepted_result_types)
#    1564
#    1565     if ret is None:
# -> 1566       ret = conversion_func(value, dtype=dtype, name=name, as_ref=as_ref)
#    1567
#    1568     if ret is NotImplemented:
#
# ~/Documentos/ReinforcementLearningTrading/test/lib/python3.7/site-packages/tensorflow/python/framework/constant_op.py in _constant_tensor_conversion_function(v, dtype, name, as_ref)
#     337                                          as_ref=False):
#     338   _ = as_ref
# --> 339   return constant(v, dtype=dtype, name=name)
#     340
#     341
#
# ~/Documentos/ReinforcementLearningTrading/test/lib/python3.7/site-packages/tensorflow/python/framework/constant_op.py in constant(value, dtype, shape, name)
#     263   """
#     264   return _constant_impl(value, dtype, shape, name, verify_shape=False,
# --> 265                         allow_broadcast=True)
#     266
#     267
#
# ~/Documentos/ReinforcementLearningTrading/test/lib/python3.7/site-packages/tensorflow/python/framework/constant_op.py in _constant_impl(value, dtype, shape, name, verify_shape, allow_broadcast)
#     274       with trace.Trace("tf.constant"):
#     275         return _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
# --> 276     return _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
#     277
#     278   g = ops.get_default_graph()
#
# ~/Documentos/ReinforcementLearningTrading/test/lib/python3.7/site-packages/tensorflow/python/framework/constant_op.py in _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
#     299 def _constant_eager_impl(ctx, value, dtype, shape, verify_shape):
#     300   """Implementation of eager constant."""
# --> 301   t = convert_to_eager_tensor(value, ctx, dtype)
#     302   if shape is None:
#     303     return t
#
# ~/Documentos/ReinforcementLearningTrading/test/lib/python3.7/site-packages/tensorflow/python/framework/constant_op.py in convert_to_eager_tensor(value, ctx, dtype)
#      96       dtype = dtypes.as_dtype(dtype).as_datatype_enum
#      97   ctx.ensure_initialized()
# ---> 98   return ops.EagerTensor(value, ctx.device_name, dtype)
#      99
#     100
#
# KeyboardInterrupt:

# %% [markdown]
# #### Creating a new environment to check agent performance in training

# %%
env = createEnv({
    "window_size": 10, 
    "data": norm_data
})

# %% [markdown]
# #### Require action until step returns Done == True

# %%
episode_reward = 0
done = False
obs = env.reset()

while not done:
    action = agent.get_action(obs)
    obs, reward, done, info = env.step(action)
    episode_reward += reward

# %%
reward

# %% [markdown]
# #### Plotting agent performance

# %%
fig, axs = plt.subplots(1, 2, figsize=(15, 5))

fig.suptitle("Performance")

axs[0].plot(np.arange(len(data["BTC:close"])), data["BTC:close"], label="price")
axs[0].set_title("Trading Chart")

performance_df = pd.DataFrame().from_dict(env.action_scheme.portfolio.performance, orient='index')
performance_df.plot(ax=axs[1])
axs[1].set_title("Net Worth")

plt.show()

# %% [markdown]
# #### Create new data to assess how the agent behaves in data you've never seen

# %%
data2 = sp.fbm(
    base_price=10000,
    base_volume=5000,
    start_date="2010-01-01",
    times_to_generate=10000,
    time_frame='1H'
)
data2 = data2.reset_index(drop=True)
data2.close.plot()

# %%
data2 = fetchTaFeatures(data2)

# %%
norm_data = pd.DataFrame(scaler.transform(data2), columns=data2.columns)

# %%
env = createEnv({
    "window_size": 10, 
    "data": norm_data
})

episode_reward = 0
done = False
obs = env.reset()

while not done:
    action = agent.get_action(obs)
    obs, reward, done, info = env.step(action)
    episode_reward += reward

# %% [markdown]
# #### Ploting performance in test data

# %%
fig, axs = plt.subplots(1, 2, figsize=(15, 5))

fig.suptitle("Performance")

axs[0].plot(np.arange(len(data2["close"])), data2["close"], label="price")
axs[0].set_title("Trading Chart")

performance_df = pd.DataFrame().from_dict(env.action_scheme.portfolio.performance, orient='index')
performance_df.plot(ax=axs[1])
axs[1].set_title("Net Worth")
# axs[1].set_xlim(0, 800)

plt.show()
